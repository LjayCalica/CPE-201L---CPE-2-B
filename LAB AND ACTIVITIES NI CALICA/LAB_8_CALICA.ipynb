# %% [markdown]
# <a href="https://colab.research.google.com/github/LjayCalica/CPE-201L---CPE-2-B/blob/main/LAB_8_CALICA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def create_queue():
    queue = []
    return queue

def is_empty(queue):
    return len(queue) == 0

def enqueue(queue, item):
    queue.append(item)
    print("Enqueued Element: " + str(item))

def dequeue(queue):
    if (is_empty(queue)):
        return "The queue is empty"
    return queue.pop(0)

def first(queue):
    if (is_empty(queue)):
        return "The queue is empty"
    return queue[0]

def queue_size(queue):
    return len(queue)

queue = create_queue()
enqueue(queue, 1)
enqueue(queue, 2)
enqueue(queue, 3)
enqueue(queue, 4)
enqueue(queue, 5)

print("The elements in the queue are: "+ str(queue))

print("Front element: " + str(first(queue)))

print("Dequeued element: " + str(dequeue(queue)))
print("Queue after dequeue: " + str(queue))

print("Queue size: " + str(queue_size(queue)))
# Out:
# Enqueued Element: 1
# Enqueued Element: 2
# Enqueued Element: 3
# Enqueued Element: 4
# Enqueued Element: 5
# The elements in the queue are: [1, 2, 3, 4, 5]
# Front element: 1
# Dequeued element: 1
# Queue after dequeue: [2, 3, 4, 5]
# Queue size: 4

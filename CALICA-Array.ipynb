# %% [markdown]
# <a href="https://colab.research.google.com/github/LjayCalica/CPE-201L---CPE-2-B/blob/main/CALICA-Array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def traverse_array(arr):
    """Function to traverse and print all elements in the array"""
    print("Traversing the array:")
    for i, element in enumerate(arr):
        print(f"Index {i}: {element}")

def reverse(arr):
  """Function to reverse the array in-place"""
  print("Reversing the array:")
  arr.reverse()
  print("Reversed array:", arr)

def delete_element(arr):
    """Function to delete an element by value"""
    value = input("Enter the value to delete: ")
    try:
        value = int(value)
        arr.remove(value)
        print(f"{value} deleted. Updated array:", arr)
    except ValueError:
        print(f"{value} not found in array.")

def insert_element(arr):
    """Function to insert an element at a specific position"""
    try:
        value = int(input("Enter the value to insert: "))
        position = int(input(f"Enter the position (0 to {len(arr)}): "))
        if 0 <= position <= len(arr):
            arr.insert(position, value)
            print(f"{value} inserted at position {position}. Updated array:", arr)
        else:
            print("Invalid position.")
    except ValueError:
        print("Invalid input. Please enter integers.")

def search_element(arr):
    """Function to search for an element in the array"""
    try:
        value = int(input("Enter the value to search: "))
        if value in arr:
            print(f"{value} found at index {arr.index(value)}")
        else:
            print(f"{value} not found in array.")
    except ValueError:
        print("Invalid input. Please enter an integer.")

def sort(arr):
    """Sort the array in ascending order"""
    arr.sort()
    print("Array sorted:", arr)

def main():
    # Initialize an array
    arr = [10, 20, 30, 40, 50]
    print("Original array:", arr)

    while True:
        print("\nMenu:")
        print("1. Traverse array")
        print("2. Reverse array")
        print("3. Insert element")
        print("4. Search element")
        print("5. Delete element")
        print("6. Sort array")
        print("7. Exit")
        choice = input("Enter your choice (1-7): ")

        if choice == '1':
            traverse_array(arr)
        elif choice == '2':
            reverse(arr)
        elif choice == '3':
            insert_element(arr)
        elif choice == '4':
            search_element(arr)
        elif choice == '5':
            delete_element(arr)
        elif choice == '6':
            sort(arr)
        elif choice == '7':
            print("Exiting the program.")
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 7.")

if _name_ == "_main_":
    main()
